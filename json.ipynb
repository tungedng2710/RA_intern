# %%
import json
f = open('/home/tungnguyen/Review/results/prediction_demo.json', 'r')

# %%
data = json.load(f)

# %%
 for i in data['test9']['prediction']:
     i['pred_bbox_x1'] = 2

# %%
data['test9']
# Out:
# {'img_h': 900,
#  'img_w': 1600,
#  'prediction': [{'pred_bbox_x1': 2,
#    'pred_bbox_y1': 95.73358154296875,
#    'pred_bbox_x2': 874.1798095703125,
#    'pred_bbox_y2': 164.6453857421875,
#    'pred_bbox_conf': 0.9990425705909729,
#    'pred_lm_1': [823.4483642578125, 122.17447662353516],
#    'pred_lm_2': [849.306396484375, 119.49777221679688],
#    'pred_lm_3': [831.5579223632812, 125.05067443847656],
#    'pred_lm_4': [823.9888305664062, 145.56988525390625],
#    'pred_lm_5': [844.7874755859375, 143.30886840820312],
#    'class': 'human'},
#   {'pred_bbox_x1': 2,
#    'pred_bbox_y1': 17.67743682861328,
#    'pred_bbox_x2': 1413.58056640625,
#    'pred_bbox_y2': 104.17578125,
#    'pred_bbox_conf': 0.9987493753433228,
#    'pred_lm_1': [1353.6387939453125, 51.393707275390625],
#    'pred_lm_2': [1375.747802734375, 44.76822280883789],
#    'pred_lm_3': [1353.454833984375, 56.333778381347656],
#    'pred_lm_4': [1353.501220703125, 79.79175567626953],
# ...

# %%
import torch
a = torch.Tensor(1, 3, 224, 224)

# %%
from torchvision import models
import torch.nn as nn
model = models.resnet34(pretrained = True)
model.fc = nn.Sequential(
        nn.BatchNorm1d(512),
        nn.Dropout(p=0.25),
        nn.Linear(512, 1)
    )
model.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
out = model(a)

# %%
out
# Out:
# tensor([[nan]], grad_fn=<AddmmBackward>)
